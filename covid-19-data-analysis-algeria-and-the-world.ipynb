# %% [markdown]
# #      <center> COVID-19 Data Analysis: Algeria and the World </center>

# %% [markdown]
# ### <center> Sami Belkacem, PhD Student in Artificial Intelligence, USTHB University </center>

# %% [markdown]
# # 1- Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import zscore

# %% [markdown]
# # 2- Read CSV file to a dataframe

# %%
df = pd.read_csv("Data.csv")

# %% [markdown]
# # 3- Preview the dataframe

# %%
df.set_index("Entity")
# Out:
#          Continent  Latitude  Longitude  Average temperature per year
# Entity
# Albania     Europe     41.15      20.17                            14  \
# Albania     Europe     41.15      20.17                            14
# Albania     Europe     41.15      20.17                            14
# Albania     Europe     41.15      20.17                            14
# Albania     Europe     41.15      20.17                            14
# ...            ...       ...        ...                           ...
# Zimbabwe    Africa    -19.02      29.15                            20
# Zimbabwe    Africa    -19.02      29.15                            20
# Zimbabwe    Africa    -19.02      29.15                            20
# Zimbabwe    Africa    -19.02      29.15                            20
# Zimbabwe    Africa    -19.02      29.15                            20
#
#           Hospital beds per 1000 people  Medical doctors per 1000 people
# Entity
# Albania                            2.89                             1.29  \
# Albania                            2.89                             1.29
# Albania                            2.89                             1.29
# Albania                            2.89                             1.29
# Albania                            2.89                             1.29
# ...                                 ...                              ...
# Zimbabwe                           1.70                             0.08
# Zimbabwe                           1.70                             0.08
# Zimbabwe                           1.70                             0.08
# Zimbabwe                           1.70                             0.08
# Zimbabwe                           1.70                             0.08
#
#           GDP/Capita  Population  Median age  Population aged 65 and over (%)
# Entity
# Albania       5353.2     2873457          38                               14  \
# Albania       5353.2     2873457          38                               14
# Albania       5353.2     2873457          38                               14
# Albania       5353.2     2873457          38                               14
# Albania       5353.2     2873457          38                               14
# ...              ...         ...         ...                              ...
# Zimbabwe      1464.0    16529904          19                                3
# Zimbabwe      1464.0    16529904          19                                3
# Zimbabwe      1464.0    16529904          19                                3
# Zimbabwe      1464.0    16529904          19                                3
# Zimbabwe      1464.0    16529904          19                                3
#
#                 Date  Daily tests    Cases  Deaths
# Entity
# Albania   2020-02-25          8.0      NaN     NaN
# Albania   2020-02-26          5.0      NaN     NaN
# Albania   2020-02-27          4.0      NaN     NaN
# Albania   2020-02-28          1.0      NaN     NaN
# Albania   2020-02-29          8.0      NaN     NaN
# ...              ...          ...      ...     ...
# Zimbabwe  2021-02-24       1804.0  35960.0  1456.0
# Zimbabwe  2021-02-25       2965.0  35994.0  1458.0
# Zimbabwe  2021-02-26          NaN  36044.0  1463.0
# Zimbabwe  2021-02-27          NaN  36058.0  1463.0
# Zimbabwe  2021-02-28          NaN  36089.0  1463.0
#
# [38472 rows x 14 columns]

# %%
df = df.groupby('Entity',axis=0).apply(lambda x: x.fillna(method='ffill'))
df = df.groupby('Entity',axis=0).apply(lambda x: x.fillna(method='bfill'))
df = df[df.Cases > 0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[66], line 2
#       1 df = df.groupby('Entity',axis=0).apply(lambda x: x.fillna(method='ffill'))
# ----> 2 df = df.groupby('Entity',axis=0).apply(lambda x: x.fillna(method='bfill'))
#       3 df = df[df.Cases > 0]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:8262, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    8259     raise TypeError("You have to supply one of 'by' and 'level'")
#    8260 axis = self._get_axis_number(axis)
# -> 8262 return DataFrameGroupBy(
#    8263     obj=self,
#    8264     keys=by,
#    8265     axis=axis,
#    8266     level=level,
#    8267     as_index=as_index,
#    8268     sort=sort,
#    8269     group_keys=group_keys,
#    8270     observed=observed,
#    8271     dropna=dropna,
#    8272 )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\groupby.py:931, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#     928 self.dropna = dropna
#     930 if grouper is None:
# --> 931     grouper, exclusions, obj = get_grouper(
#     932         obj,
#     933         keys,
#     934         axis=axis,
#     935         level=level,
#     936         sort=sort,
#     937         observed=observed,
#     938         dropna=self.dropna,
#     939     )
#     941 self.obj = obj
#     942 self.axis = obj._get_axis_number(axis)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\grouper.py:975, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#     973 if obj.ndim != 1 and gpr in obj:
#     974     if validate:
# --> 975         obj._check_label_or_level_ambiguity(gpr, axis=axis)
#     976     in_axis, name, gpr = True, gpr, obj[gpr]
#     977     if gpr.ndim != 1:
#     978         # non-unique columns; raise here to get the name in the
#     979         # exception message
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:1735, in NDFrame._check_label_or_level_ambiguity(self, key, axis)
#    1727 label_article, label_type = (
#    1728     ("a", "column") if axis_int == 0 else ("an", "index")
#    1729 )
#    1731 msg = (
#    1732     f"'{key}' is both {level_article} {level_type} level and "
#    1733     f"{label_article} {label_type} label, which is ambiguous."
#    1734 )
# -> 1735 raise ValueError(msg)
#
# ValueError: 'Entity' is both an index level and a column label, which is ambiguous.

# %% [markdown]
# # 4- Fill missing values in columns

# %%
df.isnull().sum()
# Out:
# Entity                                0
# Continent                             0
# Latitude                              0
# Longitude                             0
# Average temperature per year          0
# Hospital beds per 1000 people         0
# Medical doctors per 1000 people       0
# GDP/Capita                            0
# Population                            0
# Median age                            0
# Population aged 65 and over (%)       0
# Date                                  0
# Daily tests                        2698
# Cases                               254
# Deaths                             3610
# dtype: int64

# %% [markdown]
# # 5- Statistical description of the data

# %%
df.describe().round(2)
# Out:
#        Latitude  Longitude  Average temperature per year
# count  38472.00   38472.00                      38472.00  \
# mean      23.74      20.21                         17.72
# std       26.06      61.07                          8.13
# min      -40.90    -106.35                         -2.00
# 25%        8.62      -3.44                         11.00
# 50%       27.51      21.82                         20.00
# 75%       45.94      47.48                         25.00
# max       64.96     179.41                         29.00
#
#        Hospital beds per 1000 people  Medical doctors per 1000 people
# count                       38472.00                         38472.00  \
# mean                            3.17                             2.09
# std                             2.56                             1.52
# min                             0.20                             0.02
# 25%                             1.40                             0.82
# 50%                             2.50                             1.89
# 75%                             4.49                             3.21
# max                            13.05                             7.52
#
#        GDP/Capita    Population  Median age  Population aged 65 and over (%)
# count    38472.00  3.847200e+04    38472.00                         38472.00  \
# mean     19002.33  4.896983e+07       32.75                            10.66
# std      22271.11  1.427251e+08        8.47                             6.77
# min        411.60  3.412840e+05       16.00                             1.00
# 25%       3659.00  4.793900e+06       27.00                             5.00
# 50%       8821.80  1.148464e+07       32.00                             8.00
# 75%      25946.20  4.286296e+07       41.00                            16.00
# max     114704.60  1.339180e+09       48.00                            28.00
#
#        Daily tests        Cases     Deaths
# count     35774.00     38218.00   34862.00
# mean      35699.34    287902.66    8090.50
# std      140543.14   1405242.87   29548.75
# min     -239172.00         1.00       1.00
# 25%        1398.00      2074.00      77.00
# 50%        4870.50     21431.00     527.00
# 75%       18780.25    137377.00    3480.50
# max     2945871.00  28605669.00  513091.00

# %%
for column in df.drop(['Entity', 'Continent', 'Date', 'Daily tests', 'Cases', 'Deaths'], axis=1):
    plt.figure()
    df.boxplot([column])

# %% [markdown]
# # 6- Visualize the data

# %% [markdown]
# ## Feature distribution with histograms

# %%
columns = ['Date', 'Daily tests', 'Cases', 'Deaths']
df.drop(columns, axis=1).drop_duplicates().hist(bins=15, figsize=(16, 9), rwidth=0.8)
plt.show()

# %% [markdown]
# ## Feature correlation with a heatmap: Last cases and deaths to date

# %%
# Keep the last line (date) for each country and drop unused columns
df_last = df.groupby('Entity').tail(1).drop(['Entity', 'Date'], axis=1)
plt.figure(figsize=(12, 8))
sns.heatmap(df_last.corr(), annot=True, cmap=plt.cm.Reds)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[71], line 2
#       1 # Keep the last line (date) for each country and drop unused columns
# ----> 2 df_last = df.groupby('Entity').tail(1).drop(['Entity', 'Date'], axis=1)
#       3 plt.figure(figsize=(12, 8))
#       4 sns.heatmap(df_last.corr(), annot=True, cmap=plt.cm.Reds)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:8262, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    8259     raise TypeError("You have to supply one of 'by' and 'level'")
#    8260 axis = self._get_axis_number(axis)
# -> 8262 return DataFrameGroupBy(
#    8263     obj=self,
#    8264     keys=by,
#    8265     axis=axis,
#    8266     level=level,
#    8267     as_index=as_index,
#    8268     sort=sort,
#    8269     group_keys=group_keys,
#    8270     observed=observed,
#    8271     dropna=dropna,
#    8272 )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\groupby.py:931, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#     928 self.dropna = dropna
#     930 if grouper is None:
# --> 931     grouper, exclusions, obj = get_grouper(
#     932         obj,
#     933         keys,
#     934         axis=axis,
#     935         level=level,
#     936         sort=sort,
#     937         observed=observed,
#     938         dropna=self.dropna,
#     939     )
#     941 self.obj = obj
#     942 self.axis = obj._get_axis_number(axis)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\grouper.py:975, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#     973 if obj.ndim != 1 and gpr in obj:
#     974     if validate:
# --> 975         obj._check_label_or_level_ambiguity(gpr, axis=axis)
#     976     in_axis, name, gpr = True, gpr, obj[gpr]
#     977     if gpr.ndim != 1:
#     978         # non-unique columns; raise here to get the name in the
#     979         # exception message
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:1735, in NDFrame._check_label_or_level_ambiguity(self, key, axis)
#    1727 label_article, label_type = (
#    1728     ("a", "column") if axis_int == 0 else ("an", "index")
#    1729 )
#    1731 msg = (
#    1732     f"'{key}' is both {level_article} {level_type} level and "
#    1733     f"{label_article} {label_type} label, which is ambiguous."
#    1734 )
# -> 1735 raise ValueError(msg)
#
# ValueError: 'Entity' is both an index level and a column label, which is ambiguous.

# %% [markdown]
# ## Output variable curves with line plots

# %%
# Target countries and target dates
countries = ['Algeria', 'Bahrain', 'Ethiopia', 'Ghana', 'Kenya', 'Morocco', 'Nigeria', 'Senegal', 'Tunisia']
df_temp = df.loc[df['Date'] > '2020-02-25']

# Plot case and death curves
for output_variable in ['Cases', 'Deaths']:
    fig, ax = plt.subplots(figsize=(10, 6))
    for key, grp in df_temp[df_temp['Entity'].isin(countries)].groupby(['Entity']):
        ax = grp.plot(ax=ax, kind='line', x='Date', y=output_variable, label=key)
    plt.legend(loc='best')
    plt.xticks(rotation=90)
    plt.ylabel(output_variable)
    plt.show()

# %% [markdown]
# ## Feature-Output-variable distributions with scatter plots: Last cases and deaths to date

# %%
# Scatter plots readability: remove outliers in all comuns except in the column 'Continent'
column_continent = df_last[['Continent']]
df_last = df_last.drop('Continent', axis=1)
df_last = column_continent.join(df_last[(np.abs(zscore(df_last)) < 3).all(axis=1)])

# Plot feature-output-variable distributions for each column
for column in df_last.columns:
    fig, ax = plt.subplots(ncols=2, figsize=(14, 4))
    df_last.plot.scatter(x=column, y='Cases', ax=ax[0])
    df_last.plot.scatter(x=column, y='Deaths', ax=ax[1])
    if column == 'Continent':
        fig.autofmt_xdate(rotation=90)
