# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random as rnd
from scipy.stats import zscore

# %%
data = pd.read_csv("data.csv")
data=data.fillna(0)

# %%
data.head(20)
# Out:
#      Entity Continent  Latitude  Longitude  Average temperature per year
# 0   Albania    Europe     41.15      20.17                            14  \
# 1   Albania    Europe     41.15      20.17                            14
# 2   Albania    Europe     41.15      20.17                            14
# 3   Albania    Europe     41.15      20.17                            14
# 4   Albania    Europe     41.15      20.17                            14
# 5   Albania    Europe     41.15      20.17                            14
# 6   Albania    Europe     41.15      20.17                            14
# 7   Albania    Europe     41.15      20.17                            14
# 8   Albania    Europe     41.15      20.17                            14
# 9   Albania    Europe     41.15      20.17                            14
# 10  Albania    Europe     41.15      20.17                            14
# 11  Albania    Europe     41.15      20.17                            14
# ...

# %%
# Get dynamic data into a df
relevant_data = data[["Entity","Date","Daily tests","Cases", "Deaths"]]
relevant_data.fillna(0)
# Out:
#          Entity        Date  Daily tests    Cases  Deaths
# 0       Albania  2020-02-25          8.0      0.0     0.0
# 1       Albania  2020-02-26          5.0      0.0     0.0
# 2       Albania  2020-02-27          4.0      0.0     0.0
# 3       Albania  2020-02-28          1.0      0.0     0.0
# 4       Albania  2020-02-29          8.0      0.0     0.0
# ...         ...         ...          ...      ...     ...
# 38467  Zimbabwe  2021-02-24       1804.0  35960.0  1456.0
# 38468  Zimbabwe  2021-02-25       2965.0  35994.0  1458.0
# 38469  Zimbabwe  2021-02-26          0.0  36044.0  1463.0
# 38470  Zimbabwe  2021-02-27          0.0  36058.0  1463.0
# 38471  Zimbabwe  2021-02-28          0.0  36089.0  1463.0
#
# [38472 rows x 5 columns]

# %%
# set entity as index in data
data.set_index("Entity")
# Out:
#          Continent  Latitude  Longitude  Average temperature per year
# Entity
# Albania     Europe     41.15      20.17                            14  \
# Albania     Europe     41.15      20.17                            14
# Albania     Europe     41.15      20.17                            14
# Albania     Europe     41.15      20.17                            14
# Albania     Europe     41.15      20.17                            14
# ...            ...       ...        ...                           ...
# Zimbabwe    Africa    -19.02      29.15                            20
# Zimbabwe    Africa    -19.02      29.15                            20
# Zimbabwe    Africa    -19.02      29.15                            20
# Zimbabwe    Africa    -19.02      29.15                            20
# Zimbabwe    Africa    -19.02      29.15                            20
#
#           Hospital beds per 1000 people  Medical doctors per 1000 people
# Entity
# ...

# %%
# set entity as index
relevant_data.set_index("Entity")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 # set entity as index
# ----> 2 relevant_data.set_index("Entity")
#
# NameError: name 'relevant_data' is not defined

# %%
df.drop_duplicates()

# %%
# seaborn scaterplot
sns.histplot(data = relevant_data, x="Deaths", binwidth=3)
